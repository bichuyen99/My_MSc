# %% [markdown]
# # Problem 1

# %% [markdown]
# <h2> Problem 1.0 (Matrix norms) </h2>
#
# For any norm $\|\cdot\|$ in finite dimentional space $\mathbb{C}^{N}$ we define dual norm $\|x\|^{'} = \sup\left\{\left|y^{\star} x\right|:\left\|y\right\|=1\right\}$, where ${\cdot}^{\star}$ denotes transpose complex-conjugate vector.
# <h3>1.0.1. Prove that $\|\cdot\|^{'}$ is a norm</h3>

# %% [markdown]
# With any norm $ \left\|\cdot\right\| $ in finite dimentional space $ \mathbb{C} ^ N $, satisfy certain properties: <br>
# - $ \left\|x\right\| \geq 0 $, if $ \left\|x\right\| = 0 $ then $ x = 0 $
# - $ \left\|\alpha x\right\| = |\alpha|\left\|x\right\| $
# - $ \left\|x+y\right\| \leq \left\|x\right\| + \left\|y\right\| $ <br><br>
# To be a norm $ \left\|\cdot\right\|' $ should satisfy above properties. <br>
# Note that in finite dimentional space $ \mathbb{C} ^ N: y^{\star}x = x\cdot y = \sum\limits_{i=1}^{n}x_{i}\bar y_{i} $ <br>

# %% [markdown]
# + $x = 0: \|x\|^{'} = 0$
# + $x \neq 0:$ <br>
# We have $\hat{z} := \frac{x}{\|x\|}, \|\hat{z}\|=1$. Compare with $\|y\|=1$, so we can replace $y$ with $\hat{z}:$
# $$ \|x\|' = \sup\left\{\left|y^{\star} x\right|:\left\|y\right\|=1\right\} \\ = \sup\left\{\left|\hat{z}^{\star} x\right| \right\} = \sup\left\{\left|x\cdot\hat{z}\right| \right\} \geq \frac{\|x\|^{2}}{\|x\|} \geq 0 $$
# Therefore, $ \left\|x\right\|' \geq 0 $ for all $ x \in \mathbb{C} ^ N $, if $ \left\|x\right\|' = 0 $ then $ x = 0 ~~~~~ (1)$ <br>
# Next to the second property: <br>
# $$ \|\alpha x\|' = sup\{\alpha\cdot|y^*x|\} = |\alpha|\cdot sup{\{|y^*x|\}} = |\alpha|\cdot\|x\|' ~~~~~~ (2) $$
# Lastly, <br>
# $$ \left\|x+z\right\|' = sup\{|y^*(x+z)|\} = sup\{|y^*x+y^*z|\} \leq sup\{|y^*x|\}+ sup\{|y^*z|\} = \left\|x\right\|' + \left\|z\right\|' $$ \
# $$ \Rightarrow \left\|x+z\right\|' \leq \left\|x\right\|' + \left\|z\right\|' ~~~~~~~~~ (3) $$
# From (1), (2) and (3) we can conclude that $ \|\cdot\|' $ is a norm.

# %% [markdown]
# <h3>1.0.2. Find dual norms for Chebyshev norm $\left\|x\right\|_{\infty} = \max\limits_{i=1,\dots, N}|x_{i}|$ and $l_1$ norm $\left\|x\right\|_1 = \sum\limits_{i=1}^{N}|x_{i}|$. </h3>
#
# Let $y = (y_{1},...,y_{n}) \in \mathbb{C} ^ N$ with $\|y\|_{q} \leq 1 $ <br>
# As we know: $$y^{\star}x = x\cdot y = \sum\limits_{i=1}^{n}x_{i}\bar y_{i} \leq \sum\limits_{i=1}^{n}|x_{i}\bar y_{i}| =\|xy\|_{1} $$
# By Hölder's inequality, let $ 1 \leq p,q \leq \infty $ with $ \frac{1}{p} + \frac{1}{q} = 1$, we have <br>
# $$\|xy\|_{1} \leq \|x\|_{p}\|y\|_{q}$$
# Therefore,
# $$y^{\star}x = x\cdot y \leq \|xy\|_{1} \leq \|x\|_{p}\|y\|_{q} \leq \|x\|_{p} $$
# So we can predict that $\sup\left\{\left|{y}^{\star} x\right|, \|y\|_{q} \leq 1 \right\} = \|x\|_{p}$ <br>
# To improve that, find $z \in \mathbb{C} ^ N$ with $\|z\|_q = 1$ and $\sum_{i=1}^{n}x_iz_i=\|x\|_p.$ <br>
# Because $\|z\|_{q} = 1 $, choose $z := \frac{y}{\|y\|_{q}} ~ (\|y\|_q>0$ with $x \neq 0)$ then $$ \sum_{i=1}^{n} x_i z_i = \sum_{i=1}^{n} x_{i}\frac{y_i}{\|y\|_q} = \frac{1}{\|y\|_q}\sum_{i=1}^{n} x_i y_i  ~~~~~~ (4)$$
# Let $y_i := \text{csgn} (x_i) |x_i|^{p-1},~ i = 1,...,n$; note that $|x_{i}| = x_{i}csgn(x_i)$. <br>
# $$\sum_{i=1}^{n} x_i y_i = \sum_{i=1}^{n} x_{i}\text{csgn} (x_i)|x_i|^{p-1} =\sum_{i=1}^{n} |x_i|^p = \|x\|_p^p ~~~~~~ (5)$$
# Beside that,
# $$\|y\|_{q}^q = \sum_{i=1}^{n} |y_i|^q = \sum_{i=1}^{n} \big|csgn(x_i)|x_i|^{p-1}\big|^q = \sum_{i=1}^{n} |x_i|^{(p-1)q} = \sum_{i=1}^{n} |x_i|^p = \|x\|_p^p $$
# Here, $(p-1)q=p$ from $\frac{1}{p}+\frac{1}{q}=1$.
# $$\Rightarrow \|y\|_q = {(\|y\|_{q}^q)}^{\frac{1}{q}}={(\|x\|_{p}^p)}^{\frac{1}{q}} =\|x\|_{p}^{\frac{p}{q}} ~~~~~~ (6)$$
# From (4), (5) and (6), we have: <br>
# $$ \sum_{i=1}^{n} x_i z_i = \frac{1}{\|y\|_q}\sum_{i=1}^{n} x_i y_i = \frac{1}{\|x\|_{p}^{\frac{p}{q}}}\|x\|_p^p=\|x\|_p^{p-\frac{p}{q}}= \|x\|_p$$
# Thus we found $\|z\|_q=1$ so that $\sum_{i=1}^{n}x_iz_i=\|x\|_p$, i.e. $$ \|x\|' = \sup\left\{\left|y^{\star} x\right|:\left\|y\right\|_q=1\right\} = \|x\|_{p}$$
# Conclude that $\left\|\cdot\right\|_p$ is a dual norm of $\left\|\cdot\right\|_q$ when $ \frac{1}{p} + \frac{1}{q} = 1$ for $ 0 \leq p,q \leq \infty $

# %% [markdown]
# Therefore, <br>
# - dual norm for Chebyshev norm $ \left\|x\right\|_\infty = \max_{i = 1,...,N}|x_i| $ is $\left\|x\right\|_1 = \sum\limits_{i=1}^{N}|x_{i}|$; <br>
# - dual norm for $l_1$ norm $\left\|x\right\|_1 = \sum\limits_{i=1}^{N}|x_{i}|$ is $ \left\|x\right\|_\infty = \max_{i = 1,...,N}|x_i| $ <br>
# Because of $\frac{1}{\infty} + \frac{1}{1} = 1$

# %% [markdown]
# <h3>1.0.3. Find dual norm for $l_p$ norm $\left\|x\right\|_{p} = \left(\sum\limits_{i=1}^{N}|x_{i}|^{p}\right)^{1/p}$. </h3>
#
# From the above, we know that dual norm for $l_p$ norm $\left\|x\right\|_{p} = \left(\sum\limits_{i=1}^{N}|x_{i}|^{p}\right)^{1/p}$ is $\left\|x\right\|_q$ for $ 0 \leq q = \frac{p}{p-1} \leq \infty $ <br>
# $$ \left\|x\right\|'_p = \left\|x\right\|_q = \left(\sum\limits_{i=1}^{N}|x_{i}|^{\frac{p}{p-1}}\right)^{\frac{p-1}{p}}$$

# %% [markdown]
# <h3>1.0.4. Find dual norm for weighted norm $\left\|x\right\|_{A} = \left(x^T A x\right)^{1/2}$ with positive-definite matrix $A$ and $x\in\mathbb{R}^{N}$ </h3>
#
# With positive-definite matrix $A$ and $x\in\mathbb{R}^{N}$, exist 2 positive-definite matrix $A^\frac{1}{2}$ and $A^\frac{-1}{2}$. <br>
# Choose $ x = A^{\frac{-1}{2}}y $, we have:
# $$\left\|x\right\|_{A} = \left(x^T A x\right)^{1/2}$$
# $$\Leftrightarrow \left\|A^{\frac{-1}{2}}y\right\|_{A} = \left((A^{\frac{-1}{2}}y)^T A A^{\frac{-1}{2}}y\right)^{1/2}$$
# $$\Leftrightarrow \left\|y\right\|_{A} = \left(y^TAy\right)^{1/2}$$
# The dual norm for weighted norm $\left\|x\right\|_{A}$ is:
# $$\|x\|^{'}_{A} = \sup\left\{\left|y^{\star} x\right|:\left\|y\right\|=1\right\} = \sup\left\{\frac{\left|y^{\star} x\right|}{\left\|y\right\|}:y\neq 0\right\} =\sup\frac{\left|y^{\star} x\right|}{\sqrt{y^{T}Ay}} $$
# Then multiply both numerator and denominator with $ A^{\frac{-1}{2}}$ so
# $$\|x\|^{'}_{A} =\sup\frac{\left|(A^{\frac{-1}{2}}y)^{\star} x\right|}{\sqrt{y^{T}A^{\frac{-1}{2}}AA^{\frac{-1}{2}}y}} =\sup\frac{\left|(A^{\frac{-1}{2}}y)^{\star} x\right|}{\sqrt{y^{T}y}}= \sup\frac{\left|(A^{\frac{-1}{2}}y)^{\star} x\right|}{{\|y\|}_{2}} =$$
# $$  = \sup\frac{\left|y^{\star} (A^{\frac{-1}{2}}x)\right|}{{\|y\|}_{2}} = \frac{{{\|A^{\frac{-1}{2}}x\|}^2}_2}{\|A^{\frac{-1}{2}}x\|_2} = \|A^{\frac{-1}{2}}x\|_2 = A^{\frac{-1}{2}}\sqrt{x^{T}x} = \sqrt{x^{T}A^{-1}x}  = \|x\|_{A^{-1}} $$
# Thus $\|x\|_{A^{-1}} $ is dual norm for weighted norm $\left\|x\right\|_{A} = \left(x^T A x\right)^{1/2}$

# %% [markdown]
# <h2> Problem 1.1 (Matrix norms) </h2>
#
# Let $U \in \mathbb{R}^{n \times r}$ be an $n \times r$ matrix with orthonormal columns $U^{\top} U = I_r$. Let $V$ be an $m \times r$ matrix.
#
# <h3>1.1.1. Propose an algorithm for the computation of $\Vert A \Vert^2_F$, where $A = U V^{\top}$, and estimate its complexity with respect to $n, m, r$. How orthogonalization can be used? </h3>
#
# Apply Cauchy-Schwarz, we have:
# $$ \Vert A \Vert^2_F = \|U V^{\top}\|_F^2 = {\big|\sum_{i=1}^{n}\sum_{j=1}^{m}\sum_{k=1}^{r}u_{ik}v_{kj}\big|}^2  \leq \sum_{i=1}^{n}\sum_{j=1}^{m}\big(\sum_{k=1}^{r}|u_{ik}|^2 \sum_{k=1}^{r}|v_{kj}|^2\big) = $$ $$=\sum_{i=1}^{n}\sum_{j=1}^{m}\big(\sum_{k,l=1}^{r}|u_{ik}|^2|v_{lj}|^2\big) = \sum_{i=1}^{n}\sum_{k=1}^{r}|u_{ik}|^2 \sum_{l=1}^{r} \sum_{j=1}^{m}|v_{lj}|^2 =\|U\|_F^2 \space \|V^{\top}\|_F^2 \leq \|V^{\top}\|_F^2 $$
# Furthermore:
# $$ \Vert A \Vert^2_F = (A, A)_F = trace(A^{\top} A) = trace((UV^{\top})^{\top} UV^{\top}) = trace( (V \underbrace{U^{\top}U}_{I_r} V^{\top} ) =  trace(V V^{\top} ) = ||V^{\top}||_F^2 $$
# $$\Rightarrow \Vert A \Vert^2_F = \|V^{\top}\|_F^2 = \sum_{l=1}^{r}\sum_{j=1}^{m}|v_{lj}|^2 $$
# Thus the complexity of $\Vert A \Vert^2_F$ equal to $ \Vert V^{\top} \Vert^2_F$ and equal $O(r \times m)$ <br>
# **Algorithm:** <br>
# $V := 0$ <br>
# For l from 1 to r: <br>
# $~~~~$For j from 1 to m: <br>
# $~~~~~~~~$$V = V + (abs(v_{lj}))^2$

# %% [markdown]
# <h3>1.1.2. Consider the matrix $B = A \circ A$, where $\circ$ is the elementwise product of matrices (i.e., the elements of the matrix $B$ are squares of the elements of the matrix $A$). What is the maximal possible rank of the matrix $B$? </h3>
#
# We have matrix $A = U_{n \times r} V^{\top}_{r \times m} \Rightarrow A$ is an ${n \times m}$ matrix. <br>
# Moveover, $B = A_{n \times m} \circ A_{n \times m} \Rightarrow B$ is an ${n \times m}$ matrix. <br>
# So that the maximal possible rank of the matrix $B$ can be $min(m,n)$ <br>
# If $min(m,n) >> rank(A) = r_A$, let consider $rank(B)$ depend on $rank(A)$: <br>
# By the inequality rank of Hadamard product:
# $$rank(A \circ B) \leq rank(A)rank(B)$$
# Apply for matrix $B = A \circ A$, we have:
# $$rank(B) = rank(A \circ A) \leq (rank(A))^{2} = (r_A)^2$$
# But we can specialize this case by rewriting $A$ as a summation of rank-one matrices:
# $$ A = \sum_{i=1}^{r_A} a_i b_i^{\top} $$
# $$ \Rightarrow A \circ A = \sum_{i=1}^{r_A} \sum_{j=1}^{r_A} (a_i \circ a_j) (b_i \circ b_j)^{\top} $$
#
# The maximal possible rank of matrix $B$ is the maximum number of distinct rank-one matrices and can be written as folowing combination:
# $$ rank(B) = rank(A \circ A) \leq {r_A + 2 -1 \choose 2} = {r_A + 1 \choose 2} = \frac{(r_A + 1)!}{2!(r_A+1-2)!} = \frac{r_A(r_A + 1)}{2}$$
# $$\Rightarrow rank(B) \leq \frac{r_A(r_A + 1)}{2} $$
# Thus the maximal possible rank of the matrix $B$ is $\frac{r_A(r_A + 1)}{2}$

# %% [markdown]
# <h3>1.1.3. Propose an algorithm for the computation of $\Vert B \Vert^2_F$ and estimate its complexity with respect to $n, m, r$.</h3>
#
# 1) Multiply matrices $(U$ and $V^{\top})$: $A = U_{n \times r} V^{\top}_{r \times m} \Rightarrow A$ is an ${n \times m}$ matrix $ → 𝑶(n×m×r)$ flops <br>
# 2) Hadamard product: $B = A_{n \times m} \circ A_{n \times m} \Rightarrow B$ is an ${n \times m}$ matrix. $ → 𝑶(n×m)$ flops <br>
# Propose $n \geq m$ <br>
# 3) Compute QR decomposition of $B$: $B_{n\times m} = Q_{n\times m}R_{m\times m} → 𝑶(n×m^2)$ flops <br> where $Q$ is an $n \times m$ matrix with orthonormal columns $Q^{\top} Q = I_m; R$ is an ${m\times m}$ upper triangular matrix. <br>
# 4) Multiply matrices $(R$ and $R^{\top}) → 𝑶(m^2)$ flops.
#  $$ \Vert B \Vert^2_F = (B, B)_F = trace(B^{\top} B) = trace\big((QR)^{\top} QR\big) = trace( \underbrace{RR^{\top}}_{M_m}\underbrace{Q^{\top}Q}_{I_m}) = trace(M_m)$$
# where $M_m$ is an $m \times m$ symmetric matrix <br>
# 5) Diagonalize matrix M costs $𝑶(m^3)$ flops. <br>
# As we know a real matrix M is symmetric if and only if M can be diagonalized by an orthogonal matrix, i.e. $M=LDL^{-1}$ with $L$ orthogonal and $D$ diagonal. Therefore,
# $$ \Vert B \Vert^2_F = trace(M_m) = trace(LDL^{-1}) = trace(LL^{-1}D)= trace(D) = \sum\limits_{i=1}^{m}{\sigma}_{i}$$
# where ${\sigma}_{i}, i = 1,...,m$ are elements of diagonal matrix $D$. <br>
# 6) Compute $\Vert B \Vert^2_F =\sum\limits_{i=1}^{m}{\sigma}_{i} → 𝑶(m)$ flops. <br>
# Conclude that the complexity is $𝑶(m^3+m^2n+mnr)$

# %% [markdown]
# <h2> Problem 1.2 (Unitary and orthogonal matrices) </h2>
#
# <h3>1.2.1. Let $O\in\mathbb{R}^{n\times n}$ be orthogonal matrix. Characterise explicitly all orthogonal matrices that are positive definite. You may start with $n=2$. </h3>
#
# $O\in\mathbb{R}^{n\times n}$ is an orthogonal - positive definite matrix if it satifies folowing properties:
# + $O^{\top}O=OO^{\top}=I_n~~(*)$
# + For any $x: \|x\| \neq 0$, $(x, Ox) > 0$; where $O$ can be non-symmetric. $~~(**)$
#
# 1) n = 2: Let $O = \begin{bmatrix}a & b\\c & d\end{bmatrix}$ <br>
# From $(*)$, we have:
# $$ O^{\top}O = I_2 \Rightarrow \begin{cases} a^2 + b^2 = 1 \\ c^2 + d^2 = 1 \\ ac + bd = 0 \end{cases} $$
# Obviously, the rotation or reflection matrix satify above system of equations. <br>
# Let $O = \begin{bmatrix}\cos\theta & -\sin\theta \\ \sin\theta & \cos\theta\end{bmatrix} -$  the rotation matrix<br>
#
# From $(**)$, we have $x:= \begin{bmatrix} x_1 \\ x_2\end{bmatrix}\in\mathbb{R}^{2}/\{0\}$ - an eigenvector of $O$ that: $x^{\top} O x > 0$
# $$ x^T O x = \begin{bmatrix} x_1 & x_2\end{bmatrix} \begin{bmatrix}\cos\theta & -\sin\theta \\ \sin\theta & \cos\theta\end{bmatrix} \begin{bmatrix} x_1 \\ x_2\end{bmatrix} = (x_1^2 + x_2^2) \cos \theta > 0 \Leftrightarrow \cos \theta > 0 $$
# $$⇒ \theta = \pm \frac{\pi}{2} + 2\pi k, k \in \mathbb{Z}$$
# 2) n >2: <br>
# Apply the spectral theorem to diagonalize orthogonal matrix $O$, we have $O =P^{\top}RP$;
# where $P$ is an orthogonal matrix and $R$ is a block diagonal matrix with $2×2$ rotation matrices down the diagonal. <br>
# From the case $n = 2$, we found angle $\theta = \pm \frac{\pi}{2} + 2\pi k, k \in \mathbb{Z}$ that make $O_{2 \times 2}$ be positive definite matrix. Therefore, we can choose angle $\theta_i = \pm \frac{\pi}{2} + 2\pi k, k \in \mathbb{Z}$ for each submatrix $R_i$ of $R$.

# %% [markdown]
# <h3>1.2.2. Show that any unitary matrix from $\mathbb{C}^{n\times n}$ can be represented as a product of at most $n$ Householder reflectors. </h3>
#
# + $U\in \mathbb{C}^{n\times n}$ is an unitary matrix :
# $U^{\top}U = U U^{\top} = I_n$. <br>
# + $H$ is a householder matrix: $H = I - 2v v^{*}; $
# where $v$ is an $n\times 1$ column and $v v^{*}=1$ <br>
#
# Obviously, $H$ is unitary because of $H^{\top}H = (I - 2v v^{*})^{\top}(I - 2v v^{*})=I - 4 v v^{*}  + 4 (v v^{*})^2 = I - 4 + 4 = I.$ <br>
# Besides, a Householder matrix can transform all elements of a vector to zero, except for the first one.
# $$H\begin{bmatrix} x \\ x \\ x \\ x\end{bmatrix}=H\begin{bmatrix} x \\ 0 \\ 0 \\ 0\end{bmatrix}$$
# i.e. exist $v=\frac{x∓\|x\|_2e_1}{± \sqrt{2\|x\|_2^2 \mp \|x\|_2x_1}}; α$ is unknown constant and $e_1=(1,0,...,0)^{\top}$ such that $Hx = αe_1.$
# <br>Using the obtained property we can make arbitrary matrix $U^{\top}$ upper triangular:
# $$H_n...H_2H_1U^{\top}= \begin{bmatrix} x & x & x & ... & x \\ 0 & x & x & ... & x \\ 0 & 0 & x &... & x \\ 0 & ... & 0 & ... & x \\ 0 & 0 & 0 & 0 & x\end{bmatrix} = M$$
# Choose some $\alpha$ such that the resulting matrix $M$ is an identity matrix: $M = I_n$.
# $$ ⇒ H_n H_{n-1}...H_1 U^{\top} = I_n $$
# $$ ⇒ H_n H_{n-1}...H_1 U^{\top} U = I_n U$$
# $$ ⇒ H_n H_{n-1}...H_1 = U $$
# Thus, any unitary matrix from $\mathbb{C}^{n\times n}$ can be represented as a product of at most $n$ Householder reflectors.

# %% [markdown]
# # Problem 2
#
# We define approximate $\epsilon-$rank of matrix $A$ as $\text{rank}_{\epsilon}A = \min \left\{\text{rank}(X): \left\|A-X\right\|_{\max}\leq \epsilon\right\}$.
#
#
# <h4> 2.1. Let $f(x, y),\,x,y\in[0, 1]$ is analytic function with $\left.\partial_y^{(k)}\big|f(x, y)\right|_{y=0}\leq M$ for all $k$. Show that approximate rank of matrix $A_{ij} = f(x_i, y_j)$ where $x_{i},\,i=1,\dots,p$, $y_{j},\,j=1,\dots,q$ are arbitrary points inside $[0, 1]^2$, is bounded independent of $p$, $q$ and the choice of points. </h4>
#
# We have matrix $A=f(x_i,y_j); 1 ≤ i ≤ p, 1 ≤ j ≤ q$
# where $x_i\in {X} = [0, 1] ⊂ \mathbb{R}$ and $y_j \in {Y} = [0, 1] ⊂ \mathbb{R}$ are 2 suites of points. <br>
# Approximate $f(x,y)$ by a truncated Taylor series at some point $z\in {Y}$:
# $$f(x,y)≈f_p(x,y) = \sum_{k=0}^{r-1} \frac{\partial_y^{(k)}f(x,z)}{k!}(y-z)^k$$
# Consider matrix $\tilde A=f_p(x_i,y_j), 1 ≤ i ≤ p, 1 ≤ j ≤ q ⇒ \tilde A ≈ A $ <br>
# Moveover, $$rank(\tilde A)≤r$$
# If $\left.\partial_y^{(k)}\big|f(x, y)\right|_{y=0}\leq M, ∀k,$ then for any $ϵ>0$
# $$\|A-\tilde A\|_F=O(ϵ)$$ while $r=O(logϵ^{-1})$
# $$⇒\text{rank}_{\epsilon}A = \min \left\{\text{rank}(\tilde A): \left\|A-\tilde A\right\|_{\max}\leq \epsilon\right\}$$

# %% [markdown]
# <h4> 2.2. Extend result from the previous point (a.) to $x, y \in \mathbb{R}^{N}$. Observe how the bound depends on $N$. </h4>
#
# We have matrix $A_n=[f(x_i^{(n)},y_j^{(n)})], 0 ≤ i,j ≤ n$
# where $x_1^{(n)},..., x_n^{(n)} \in {X} ⊂ \mathbb{R}$ and $y_1^{(n)},..., y_n^{(n)} \in {Y} ⊂ \mathbb{R}$ are 2 suites of points. <br>
# Approximate $f(x,y)$ by a truncated Taylor series at some point $z\in {Y}$:
# $$f(x,y)≈f_p(x,y) = \sum_{k=0}^{r-1} \frac{\partial_y^{(k)}f(x,z)}{k!}(y-z)^k$$
# Consider matrix $\tilde A_n=[f_p(x_i^{(n)},y_j^{(n)})], 0 ≤ i,j ≤ n ⇒ \tilde A_n ≈ A_n $ <br>
# Moveover, $$rank(\tilde A_n)≤r$$
# If $\left.\partial_y^{(k)}\big|f(x, y)\right|_{y=0}\leq M, ∀k,$ then for any $ϵ>0$
# $$\|A_n-\tilde A_n\|_F=O(nϵ)$$ while $r=O(logϵ^{-1})$
#
# <h4> 2.3. Demonstarate your bounds from two previous points numerically on functions </h4>
#
# <h5> 2.3.1. $\cos(xy)$, $\exp(-(x-y)^2)$ and a few on your choice for $N=1$ </h5>
# <h5> 2.3.2. [RBF kernel](https://scikit-learn.org/stable/modules/gaussian_process.html#radial-basis-function-rbf-kernel) for different $N$. </h5>
# <h5> 2.3.3.  [Exp-Sine-Squared kernel](https://scikit-learn.org/stable/modules/gaussian_process.html#exp-sine-squared-kernel) for different $N$.</h5>

# %% [markdown]
# <h2> Problem 3 (Molecules) </h2>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# We have in our posession a database with molecules. Each molecule has five atoms `A`, `B`, `C`, `D`, `E` located in the same plane $x, y$.
#
# The coordinates of the molecules was collected by an automatic system that processed "pictures" from the electronic microscope. As a result, some of the samples differs by unknown rotation in $2D$ space. Your task is to normalize this database to find distinct molecules.

# %%
data = pd.read_csv("https://raw.githubusercontent.com/oseledets/nla2022/main/hw1/molecules.csv", index_col=0)
data.head()
# Out:
#         A_x  A_y       B_x       B_y       C_x       C_y       D_x       D_y  \
# sample
# 0       0.0  0.0 -0.568099 -0.822960  0.411480 -0.284050 -0.983627 -0.180214
# 1       0.0  0.0 -0.816462  0.577399  0.288700  0.408231 -0.169043  0.985609
# 2       0.0  0.0 -0.999628 -0.027283  0.013642 -0.499814 -0.726136  0.687551
# 3       0.0  0.0  0.946140  0.323758 -0.161879  0.473070 -0.897953  0.440091
# 4       0.0  0.0 -0.901767  0.432222 -0.216111 -0.450884  0.332018 -0.943273
#
#              E_x       E_y
# sample
# 0      -0.180214  0.983627
# 1       0.169043 -0.985609
# 2       0.687551  0.726136
# 3      -0.440091 -0.897953
# 4       0.943273  0.332018

# %%
molecules = data.to_numpy().reshape(len(data), 5, 2)
molecules.shape
# Out:
# (500, 5, 2)

# %%
def draw_molecule(ax, molecule):
    ax.scatter(*molecule.T, color="black", s=50)
    for i in range(1, molecule.shape[0]):
        ax.plot(*molecule[[0, i], :].T, color="black")
    ax.axis("off")
    ax.axis("equal")

# %%
k = 5
fig, ax = plt.subplots(k, k, figsize=(2*k, 2*k))
ax = ax.reshape(-1,)
for i in range(k**2):
    draw_molecule(ax[i], molecules[i])

# %% [markdown]
# ## What you should do:
#
# + Prove that orthogonal transformations preserve $l_2$ norm, i.e., $\left\|x\right\|_2 = \left\|Ux\right\|_2$, where $U$ is an orthogonal matrix.

# %% [markdown]
# $$\left\|Ux\right\|_2 = \langle Ux,Ux \rangle_2 = \langle x,U^{\top}Ux\rangle_2 = \langle x,x\rangle_2 = \left\|x\right\|_2$$

# %% [markdown]
# + Use the result from the previous point to construct an algorithm that distinguishes different molecules. Implement it and run on the database. Produce a list of distinct molecules and visualise them.

# %%
import torch.nn as nn
import torch
import numpy as np
from scipy.stats import ortho_group

# %%
#Create a random orthogonal U
U = ortho_group.rvs(dim=5) 
np.dot(np.transpose(U), U)
# Out:
# array([[ 1.00000000e+00,  2.86178432e-16, -1.02236520e-16,
#         -1.13201449e-16, -8.16876213e-17],
#        [ 2.86178432e-16,  1.00000000e+00, -3.83618088e-17,
#         -4.64343295e-17,  6.55706206e-17],
#        [-1.02236520e-16, -3.83618088e-17,  1.00000000e+00,
#         -2.14659490e-16, -5.69491054e-17],
#        [-1.13201449e-16, -4.64343295e-17, -2.14659490e-16,
#          1.00000000e+00, -3.89094280e-16],
#        [-8.16876213e-17,  6.55706206e-17, -5.69491054e-17,
#         -3.89094280e-16,  1.00000000e+00]])

# %% [markdown]
# As proved, orthogonal transformations preserve  $l_2$  norm. So we find different molecules by comparing their $l_2$ norm. (up to the 14th decimal places)

# %%
distinct_norm = []
distinct_mol = []

for i in range(molecules.shape[0]):
  current = molecules[i]
  dot = np.dot(U, current)
  norm = round(np.linalg.norm(dot, 2),15)

  if norm not in distinct_norm:
    distinct_norm.append(norm)
    distinct_mol.append(current)

len(distinct_mol)
# Out:
# 6

# %%
k = 3
fig, ax = plt.subplots(int(len(distinct_mol)/k), k, figsize=(10, 10))
ax = ax.reshape(-1,)
for i, mol in enumerate(distinct_mol):
  draw_molecule(ax[i], mol)

# %% [markdown]
# + Learn about [Kabsch algorithm](https://en.wikipedia.org/wiki/Kabsch_algorithm). Implement it and run on the database. Produce a list of distinct molecules and visualise them.

# %%
def kabsch(P, Q):
  # translation: center the points
  centr_P = np.mean(P, axis=0)
  centr_Q = np.mean(Q, axis=0)
  P -= centr_P
  Q -= centr_Q

  # covariance matrix: 
  H = np.dot(np.transpose(P), Q)

  # svd decomp
  U, S, Vt = np.linalg.svd(H)
  d = (np.linalg.det(U) * np.linalg.det(Vt)) < 0.0
  if d:
    S[-1] = -S[-1]
    U[:, -1] = -U[:, -1]

  # create rotation matrix R
  R = np.dot(U, Vt)
  return R

def rmsd(V, W):
    D = len(V[0])
    N = len(V)
    rmsd = 0.0
    for v, w in zip(V, W):
        rmsd += sum([(v[i] - w[i])**2.0 for i in range(D)])
    return np.sqrt(rmsd/N)

def kabsch_rmsd(P, Q):
  R = kabsch(P, Q)
  P_rotate = np.dot(P, R)
  error = rmsd(P_rotate, Q)
  return error

# %%
distinct_mol2 = [molecules[0]]

for i in range(1, molecules.shape[0]):
  same = False
  current = molecules[i]

  for existing_mol in distinct_mol2:
    error = kabsch_rmsd(current, existing_mol)
    if error <= 1e-14:
      same = True
  
  if same == False:
    distinct_mol2.append(current)


len(distinct_mol2)
# Out:
# 5

# %%
k = 5
fig, ax = plt.subplots(int(len(distinct_mol2)/k), k, figsize=(10, 10))
ax = ax.reshape(-1,)
for i, mol in enumerate(distinct_mol2):
  draw_molecule(ax[i], mol)

# %% [markdown]
# + Compare results of algorithm from 2. and from 3. Explain the difference.

# %% [markdown]
# The number of different molecules is 3 by the first algorithm, less than the second ones 2 molecules. Because:
# - The first algorithm operates by comparing the different of molecules's norm. Firstly, a random orthogonal matrix U is created, which has UTU approximate to I. Therefore, there is not an absolutely accuracy. Secondly, the result can be changed dramatically while the rounding is changed. Here, my rounding up to 14 decimals and received 3 mocules. It will be 8 when rounding 15 decimals.
# - The second is Kabsch algorithm - a method for calculating the optimal rotation matrix that minimizes the RMSD (root mean squared deviation) between two paired sets of points. If we calculate the error up to 1e−14,  we will receive 5 mocules. When it is 1e−15, the number of mocules is 6 - a slightly different.
#
# Thus I think Kabsch algorithm is more accuracy.

# %% [markdown]
# # Problem 4 (Disentangled representation) (12 pts)

# %% [markdown]
# ## Brief intro

# %% [markdown]
# The main component of [GAN](https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html) is Generator network. Generator is such model that takes as input random vector and produces an image. In this task, we will work with the already pre-trained generator $G$. Here are a few things you need to know about this model:
#
#
#
# 1.   **Model input:** batch of random vectors $z\sim N(0,1)$ with normally distributed values of size **(Batch_Size,100)**. Here, Batch_Size is a number of images we want to generate
# 2.   **Model output:** $\mathrm{images} = G(z)$ - batch of images with size **(Batch_Size,3,64,64)**. Here **3** - defines number of image channels (3 for RGB images), **64, 64** - width and height.
# 3.   **Model structure:** generator is a set of sequentially appplied functions. Each function input is the output of the previous one. In other words, $G(z) = f_N(f_{N-1}...f_1(f_0(z)))$. $N$ - defines number of functions in generator.

# %% [markdown]
# ### Disentanglement

# %% [markdown]
# The good property of GAN is that generator input space has a set of meaningful directions - moving input vector along this directions produce interpretable changes in image. For example, we can change a Pose, Age, Expression or even add eyeglasses. You can read more about it on [resource](https://genforce.github.io/interfacegan/). The main question is how to find such good directions. This problem is called disentanglement.

# %% [markdown]
# ![](https://github.com/genforce/interfacegan/blob/master/docs/assets/teaser.jpg?raw=true)

# %% [markdown]
# ## Problem discription

# %% [markdown]
# We are going to find meaningful directions using SVD applied over the Jacobian matrix of some hidden output with respect to model input. **i-th** hidden output of generator model is defined by formula $G_{i}(z) = f_i(f_{i-1}...f_1(f_0(z))))$, where $i < N$. So, the task could be splitted on four main parts:
#
# 1. **(4 pts)**   Write the function **Get_Hidden_Output**, which reproduces formula $G_{i}(z) = f_i(f_{i-1}...f_1(f_0(z))))$
# 2. **(3 pts)**   Calculate jacobian matrix $J$ of generator $G$ for several **i** values. For each of them:
#
# *   Calculate the jacobian matrix with respect to $z$: $\frac{\partial G(z)}{\partial z}$
# *   Reshape jacobian matrix to have the size **(Batch_Size * Hidden_Output_Size,100)**
#
# 3. **(3 pts)**  Apply SVD to jacobian matrix ($J = U @ S @ V.T$) from previous step
#
# 4. **(2 pts)**  Take several directions from matrix $V$ (particular columns), and run visualization code (already written for you). Leave a comment on what you got (how found directions affect image)
#
# **Attention!!!**
#
# 1.  Please run the code on google colab to fulfil packages requirements
# 2.  Jacobian matrix computation may take more than 20 minutes!
# 3.  Use GPU runtime to accelerate computations

# %% [markdown]
# ## Prerequisites

# %%
# !pip install functorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |██████████████████████████████  | 834.1 MB 1.2 MB/s eta 0:00:47tcmalloc: large alloc 1147494400 bytes == 0x658ec000 @  0x7f9d5a298615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4bac0a 0x538a76 0x590ae5 0x510280 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e
#      |████████████████████████████████| 890.2 MB 7.0 kB/s
# ...
#      |████████████████████████████████| 317.1 MB 31 kB/s
# ...
#      |████████████████████████████████| 849 kB 51.3 MB/s
# ...
#      |████████████████████████████████| 557.1 MB 11 kB/s
# ...
#      |████████████████████████████████| 21.0 MB 1.2 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
# ...

# %%
import torch
from torch import nn
import requests
import matplotlib.pyplot as plt
import numpy as np
from torchvision import utils as vutils
from torchvision import transforms
from tqdm import tqdm
from google.colab import files
from functorch import vmap, jacfwd, jacrev
from functorch.experimental import replace_all_batch_norm_modules_
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /usr/local/lib/python3.7/dist-packages/torchvision/image.so: undefined symbol: _ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIlEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   warn(f"Failed to load image Python extension: {e}")

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
#   hidden generator size
ngf = 64

# Number of channels in the training images. For color images this is 3
nc = 3

# Size of z latent vector (i.e. size of generator input)
nz = 100

print(f"Device: {device}, latent size {nz}, generator hidden dim {ngf}, number of image channels {nc}")
# Out:
# Device: cuda:0, latent size 100, generator hidden dim 64, number of image channels 3

# %%
def download_file_from_google_drive(id, destination):
    URL = "https://docs.google.com/uc?export=download"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value

    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768

    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)

# %%
class Generator(nn.Module):
    def __init__(self, ngpu):
        super(Generator, self).__init__()
        self.ngpu = ngpu
        self.main = nn.Sequential(
            # input is Z, going into a convolution
            nn.ConvTranspose2d( nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            # state size. (ngf*8) x 4 x 4
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            # state size. (ngf*4) x 8 x 8
            nn.ConvTranspose2d( ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            # state size. (ngf*2) x 16 x 16
            nn.ConvTranspose2d( ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),
            # state size. (ngf) x 32 x 32
            nn.ConvTranspose2d( ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
            # state size. (nc) x 64 x 64
        )
    def get_function_output(self, inp, index=0):
      if index == 0:
        inp = inp[:,:,None,None]
      return self.main[index](inp)
    def get_number_of_layers(self):
      return len(self.main)

    def forward(self, input):
        return self.main(input[:,:,None,None])

# %%
file_id = "1hIh2-8KjcUku1Dl-mLYqEObbODrCW_Fp"
destination = './G_checkpoint.pt'
download_file_from_google_drive(file_id, destination)
G = Generator(1).to(device)
G.load_state_dict(torch.load('./G_checkpoint.pt', map_location="cpu"))
replace_all_batch_norm_modules_(G)
# Out:
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (11): ReLU(inplace=True)
# ...

# %%
def sample_batch(batch_size):
  return torch.randn((batch_size,nz),device=device)

# %%
def ToPILImage(tensor):
  return transforms.ToPILImage()(tensor)

# %%
def ConvertTensorsToOne(tensor, nrow=None):
  if nrow is None:
    nrow = int(tensor.size(0) ** 0.5)
  return vutils.make_grid(tensor, padding=2, normalize=True, nrow=nrow).cpu()

# %% [markdown]
# ## Generator network visualization

# %%
# generator model consist of 14 functions numbered from 0 to 13

G
# Out:
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (11): ReLU(inplace=True)
# ...

# %%
# sample 64 random vectors to produce 64 images

z = sample_batch(64)

z.shape
# Out:
# torch.Size([64, 100])

# %%
# producing images

out = G(z)

out.shape
# Out:
# torch.Size([64, 3, 64, 64])

# %%
# generate hidden output for given input (remember that functions are applied sequentially - input should be the output of previous function)
# index defines which function output will be returned
# for function with index 0 input will be model input "z"

hidden_output = G.get_function_output(z,index=0)

hidden_output.shape
# Out:
# torch.Size([64, 512, 4, 4])

# %%
# plotting the images by combining them into one, with 8 images in each row (nrow=8)

plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Generator output")
plt.imshow(ToPILImage(ConvertTensorsToOne(out, nrow=8)))

# %% [markdown]
# ## Perform experiments

# %% [markdown]
# **Define the function that returns the output of any generator function for given input z and generator function index**

# %%
def Get_Hidden_Output(z,index):
  out = None
  for i in range(index+1):
    if out is None:
      out = G.get_function_output(z,index=i)
    else:
      out = G.get_function_output(out,index=i)
  return out

# %% [markdown]
# **Define the function that calculates the jacobian matrix based on given input z and generator function index (use the function which you implemented earlier)**

# %%
def Calc_Gradient(z, index):
  jac = jacfwd(Get_Hidden_Output)
  grads = vmap(jac, (0,None))(z.unsqueeze(1), index).reshape(-1,100)
  print(grads.shape)
  return grads

# %%
z = sample_batch(20)
index = [1, 3, 9]
grads = []
for i in index:
  grad = Calc_Gradient(z, i)
  grads.append(grad)
# Out:
# torch.Size([163840, 100])
# torch.Size([327680, 100])
# torch.Size([1310720, 100])

# %% [markdown]
# **Calculate SVD and visualize singular values for several generator function indexes (2-3 indexes are enough). Based on singular value plots, decide what generator function is more useful for disentangled representation search and why, leave a comment.**

# %%
for i in range(len(index)):
  U, S, V = torch.linalg.svd(grads[i], full_matrices=False)
  plt.plot(S.cpu().detach().numpy(), '-' )
plt.legend([f'G_{index[0]}',f'G_{index[1]}',f'G_{index[2]}'])

# %% [markdown]
# Based on singular value plots, between 3 values of generator function (G_1, G_3,G_9); G_9 is more useful for disentangled representation search. Because it has a bigger impact on the output with its wide range value.

# %% [markdown]
# **Choose some directions from matrix V (some columns) corresponding to chosen generator function index (based on previous step). Run visualization code. Which directions attributes affects chosen image?**

# %%
def make_edit(input, dirs):
  output = G(input)
  input_shift = input[:,None,:] + dirs[None,:,:]*3
  output_shift = G(input_shift.reshape(-1,nz)).reshape(input.size(0),-1,3,64,64)
  return torch.cat([output[:,None],output_shift],dim=1).reshape(-1,3,64,64)

# %%
input = sample_batch(4)
dirs = V[:5]

# %%
out = make_edit(input, dirs)
plt.figure(figsize=(16,16))
plt.axis("off")
plt.imshow(ToPILImage(ConvertTensorsToOne(out, nrow=(dirs.size(0)+1))))
