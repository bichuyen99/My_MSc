# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
from skimage import io

# %%
def plot_img(img, cmap='gray'):
    plt.figure(figsize=(14,5))
    plt.imshow(img, cmap=cmap)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Image

# %%
img = np.float32(cv2.imread('table_0.png', 0))

plot_img(img)

# %% [markdown]
# ## Task

# %% [markdown]
# The main goal is to remove the table from image using morphology operations.
#
# Example of the output is given below.

# %% [markdown]
# ## Solution

# %%
def remove_table_pipeline(img):
    raise NotImplementedError
    
    
res = remove_table_pipeline(img)

# %%
plot_img(res)
